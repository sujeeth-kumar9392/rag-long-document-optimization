# %% [markdown]
# <a href="https://colab.research.google.com/github/sujeeth-kumar9392/rag-long-document-optimization/blob/main/01_document_loading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
mkdir -p /content/drive/MyDrive/rag_project/{data,notebooks,src,results,report}

# %%
ls /content/drive/MyDrive/rag_project
# Out:
# data/  notebooks/  report/  results/  src/
